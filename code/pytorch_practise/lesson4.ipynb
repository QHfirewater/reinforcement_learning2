# %%
import torch

# %% [markdown]
# ## 梯度

# %% [markdown]
# ### 寻找极小值

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 影响找到最小值的因素

# %% [markdown]
# ### 初始状态

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 学习率

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 逃出局部最小值

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 常见函数的梯度

# %% [markdown]
# ![image.png](attachment:image.png)
